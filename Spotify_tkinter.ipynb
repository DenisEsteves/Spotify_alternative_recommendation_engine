# %%
from tkinter import *
from PIL import ImageTk, Image
import webbrowser
from tkinter import font
import os
import random
import webbrowser
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials("9c24b7e194394db78e3435d96a43a0d6","264f811e265b44379dcf365b69b1145e"))

# %%
#Different functions:
def cluster0():
     webbrowser.open("https://p.scdn.co/mp3-preview/5cb4578e046e2b68876c89d6da131f834bc66486?cid=9c24b7e194394db78e3435d96a43a0d6")
def cluster1():
     webbrowser.open("https://p.scdn.co/mp3-preview/482469884abd29865499b6cb6d5d9f17668afd70?cid=9c24b7e194394db78e3435d96a43a0d6")
def cluster2():
     webbrowser.open("https://p.scdn.co/mp3-preview/8cf57563d7553159042a312443ae361880c57b41?cid=9c24b7e194394db78e3435d96a43a0d6")
def cluster3():
     webbrowser.open("https://p.scdn.co/mp3-preview/fa707f13566ee70810e6a822bbf9a731a78a780d?cid=9c24b7e194394db78e3435d96a43a0d6")
def cluster4():
     webbrowser.open("https://p.scdn.co/mp3-preview/3212ab03cd01b97d2b9fdadaa89ff9fbe323bffd?cid=9c24b7e194394db78e3435d96a43a0d6")
def cluster5():
     webbrowser.open("https://p.scdn.co/mp3-preview/dcfda3c0a34ee95e7c9bcddda8429a3a0879dfb5?cid=9c24b7e194394db78e3435d96a43a0d6")
def cluster6():
     webbrowser.open("https://p.scdn.co/mp3-preview/e271efe91424107fb0e7e4e2c5fa24e4abdd33d0?cid=9c24b7e194394db78e3435d96a43a0d6")
def cluster7():
    webbrowser.open("https://p.scdn.co/mp3-preview/a45d38b6e3b93ec0a60ff122546805e6c64ee2f7?cid=9c24b7e194394db78e3435d96a43a0d6")
def cluster8():
    webbrowser.open("https://p.scdn.co/mp3-preview/c5bf52fbd83545d17cb52e91da5694075173b54c?cid=9c24b7e194394db78e3435d96a43a0d6") 
def cluster9():
     webbrowser.open("https://p.scdn.co/mp3-preview/44a14bd01aee71770b24d91f871a00ccc23568d5?cid=9c24b7e194394db78e3435d96a43a0d6") 

        
def lista0():
    eleccionesa.append(0)
def lista1():
    eleccionesa.append(1)
def lista2():
    eleccionesb.append(2)
def lista3():
    eleccionesa.append(3)
def lista4():
    eleccionesb.append(4)
def lista5():
    eleccionesa.append(5)
def lista6():
    eleccionesa.append(6)    
def lista7():
    eleccionesb.append(7)
def lista8():
    eleccionesb.append(8)
def lista9():
    eleccionesa.append(9)
    
prueba={0:"https://open.spotify.com/playlist/6vOVu0qGc4HivbQgobyGfL", 1:"https://open.spotify.com/playlist/6Qxs2jMezzwPiMO1bEvPca", 2:"https://open.spotify.com/playlist/1w3y4QovuTaNnSF3MRIqWY" , 3: "https://open.spotify.com/playlist/3HGwGoYXxkXwsxocDfzfig" ,4: "https://open.spotify.com/playlist/4jOGptPy8CH4on6XTbgW69" , 5: "https://open.spotify.com/playlist/3nrM28WoSb4Qo6NcwKddOQ" ,6: "https://open.spotify.com/playlist/2u12mWd6ktzt1mVa7wrNdd" , 7: "https://open.spotify.com/playlist/4cIFAegwRCPfN4eNr2OXHX", 8: "https://open.spotify.com/playlist/0aUUKndhao5ivyAp7BWqK7",9: "https://open.spotify.com/playlist/0nMZ7w7f8oNtDMSIiaJgaE"}
eleccionesb=[]
eleccionesa=[]

ventana=Tk()
ventana.title("Spotify Recommendation Engine")
ventana.geometry("1200x600")
ventana.iconbitmap("C:/Users/Portu/Desktop/Spotify/icono.ico")
ventana.configure(background= "#1DB954")

img=Image.open("C:/Users/Portu/Desktop/Spotify/icono.png")
resized=img.resize((300,200), Image.ANTIALIAS)
new_pick=ImageTk.PhotoImage(resized)
my_label=Label(ventana, image=new_pick)
my_label.pack(padx=20,pady=20)

def open ():
    top=Toplevel()
    top.iconbitmap("C:/Users/Portu/Desktop/Spotify/icono.ico")
    top.title("First Question")
    top.geometry("1200x600")
    top.configure(background= "#1DB954")
    boton_salir1=Button(top,text="Leave me go!", command= ventana.destroy,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_salir1.place(x=525,y=380)
    
    boton70=Button(top,text="I prefer music before 70's",padx=10, pady=10, command=before70, background="#d2af23",foreground="#002270",anchor="center",font=Helvfont)
    boton70.place(x=200,y=300)
    
    botona70=Button(top,text="Newer music, please",padx=10, pady=10, command=after70, background="#d2af23",foreground="#002270",anchor="center",font=Helvfont)
    botona70.place(x=600,y=300)

def before70(): 
    top70=Toplevel()
    top70.title("Second Question")
    top70.geometry("1200x600")
    top70.iconbitmap("C:/Users/Portu/Desktop/Spotify/icono.png")
    top70.configure(background= "#1DB954")
    boton_salir2=Button(top70,text="Leave me go!", command= ventana.destroy,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_salir2.place(x=525,y=380)

    
    #2 preguntas de 2
    global my_img7
    global my_img8
    
    my_img7=ImageTk.PhotoImage(Image.open("C:/Users/Portu/Desktop/Spotify/cluster7.ico"))
    my_label7=Label(top70,image=my_img7).pack()
    boton_701=Button(top70,text="Listen a trial of the song", command= cluster7 ,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_701.place(x=200,y=100)
   
    my_img8=ImageTk.PhotoImage(Image.open("C:/Users/Portu/Desktop/Spotify/cluster8.ico"))
    my_label8=Label(top70,image=my_img8).pack()
    boton_7011=Button(top70,text="Listen a trial of the song", command=cluster8,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_7011.place(x=200,y=300)

    
    boton_701e=Button(top70,text="I prefer this song", command= lambda:[before701(),lista7()] ,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_701e.place(x=800,y=100)
    boton_7011e=Button(top70,text="I prefer this song", command= lambda:[before701(),lista8()],background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_7011e.place(x=800,y=300)
    
    boton_salir70=Button(top70,text="Leave me go!", command= ventana.destroy,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_salir70.place(x=50,y=50)
    
def before701(): 
    top701=Toplevel()
    top701.title("Third Question")
    top701.geometry("1200x600")
    top701.iconbitmap("C:/Users/Portu/Desktop/Spotify/icono.png")
    top701.configure(background= "#1DB954")
    boton_salir21=Button(top701,text="Leave me go!", command= ventana.destroy,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_salir21.place(x=525,y=380)
    
    global my_img4
    global my_img2
    
    my_img4=ImageTk.PhotoImage(Image.open("C:/Users/Portu/Desktop/Spotify/cluster4.ico"))
    my_label4=Label(top701,image=my_img4).pack()
    boton_7014=Button(top701,text="Listen a trial of the song", command=cluster4 ,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_7014.place(x=200,y=100)
   
    my_img2=ImageTk.PhotoImage(Image.open("C:/Users/Portu/Desktop/Spotify/cluster2.ico"))
    my_label2=Label(top701,image=my_img2).pack()
    boton_70112=Button(top701,text="Listen a trial of the song", command=cluster2,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_70112.place(x=200,y=300)

    
    boton_701e4=Button(top701,text="I prefer this song", command= lambda:[final70(),lista4()] ,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_701e4.place(x=800,y=100)
    boton_7011e2=Button(top701,text="I prefer this song", command=lambda:[final70(),lista2()] ,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_7011e2.place(x=800,y=300)
    
    boton_salir701=Button(top701,text="Leave me go!", command= ventana.destroy,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_salir701.place(x=50,y=50)
    
def pre(element):
    webbrowser.open(element)
    ventana.destroy()
        #ventana.destroy
        
def opo(element):
    for key, value in prueba.items():
        if key == element:
            webbrowser.open(value)
def opo2 (element):
    for key, value in prueba.items():
        if key==element:
            webbrowser.open(value)
    
    
def final70():
    top703=Toplevel()
    top703.title("Your elect")
    top703.geometry("1200x600")
    top703.iconbitmap("C:/Users/Portu/Desktop/Spotify/icono.ico")
    top703.configure(background= "#1DB954")
    if len(eleccionesa)>len(eleccionesb):
            a= random.choice(eleccionesa)
            botonprueba=Button(top703,text="Here you have your recommendation!", command= lambda:[pre, opo(a)],background="#d2af23",foreground="#002270",anchor="center",font=Helvfont)
            botonprueba.place(x=350, y=300)

    else:
            b= random.choice(eleccionesb)
            botonprueba2=Button(top703,text="Here you have your recommendation!", command=lambda:[pre,opo2(b)],background="#d2af23",foreground="#002270",anchor="center",font=Helvfont)
            botonprueba2.place(x=350, y=300)


    
def after70():
    top70a=Toplevel()
    top70a.title("Second Question")
    top70a.geometry("1200x600")
    top70a.iconbitmap("C:/Users/Portu/Desktop/Spotify/icono.ico")
    top70a.configure(background= "#1DB954")
    boton_salir3=Button(top70a,text="Leave me go!", command= ventana.destroy,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_salir3.place(x=525,y=380)
    
    #3 preguntas de 2
    global my_img3
    global my_img5
    
    my_img3=ImageTk.PhotoImage(Image.open("C:/Users/Portu/Desktop/Spotify/cluster3.ico"))
    my_label3=Label(top70a,image=my_img3).pack()
    boton_701a=Button(top70a,text="Listen a trial of the song", command= cluster3 ,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_701a.place(x=200,y=100)
   
    my_img5=ImageTk.PhotoImage(Image.open("C:/Users/Portu/Desktop/Spotify/cluster5.ico"))
    my_label5=Label(top70a,image=my_img5).pack()
    boton_7011a=Button(top70a,text="Listen a trial of the song", command=cluster5,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_7011a.place(x=200,y=300)

    
    boton_701ea=Button(top70a,text="I prefer this song", command= lambda:[after1(), lista3()] ,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_701ea.place(x=800,y=100)
    boton_7011ea=Button(top70a,text="I prefer this song", command=lambda:[after1(), lista5()],background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_7011ea.place(x=800,y=300)
    
    boton_salir70a=Button(top70a,text="Leave me go!", command= ventana.destroy,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_salir70a.place(x=50,y=50)
    
def after1():
    top7011a=Toplevel()
    top7011a.title("Third Question")
    top7011a.geometry("1200x600")
    top7011a.iconbitmap(r"C:/Users/Portu/Desktop/Spotify/icono.png")
    top7011a.configure(background= "#1DB954")
    boton_salir211a=Button(top7011a,text="Leave me go!", command= ventana.destroy,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_salir211a.place(x=525,y=380)
    
    global my_img0
    global my_img1
    
    my_img0=ImageTk.PhotoImage(Image.open("C:/Users/Portu/Desktop/Spotify/cluster0.ico"))
    my_label0=Label(top7011a,image=my_img0).pack()
    boton_701a2=Button(top7011a,text="Listen a trial of the song", command= cluster0 ,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_701a2.place(x=200,y=100)
   
    my_img1=ImageTk.PhotoImage(Image.open("C:/Users/Portu/Desktop/Spotify/cluster1.ico"))
    my_label1=Label(top7011a,image=my_img1).pack()
    boton_701a22=Button(top7011a,text="Listen a trial of the song", command= cluster1 ,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_701a22.place(x=200,y=300)

    
    boton_701ea2=Button(top7011a,text="I prefer this song", command= lambda:[after2(), lista0()],background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_701ea2.place(x=800,y=100)
    boton_7011ea2=Button(top7011a,text="I prefer this song", command=lambda:[after2(),lista1()],background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_7011ea2.place(x=800,y=300)
    boton_salir70a1=Button(top7011a,text="Leave me go!", command= ventana.destroy,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_salir70a1.place(x=50,y=50)
def after2():
    top7a2=Toplevel()
    top7a2.title("Fourth Question")
    top7a2.geometry("1200x600")
    top7a2.iconbitmap(r"C:/Users/Portu/Desktop/Spotify/icono.png")
    top7a2.configure(background= "#1DB954")
    boton_salir70a2=Button(top7a2,text="Leave me go!", command= ventana.destroy,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_salir70a2.place(x=525,y=380)
    
    global my_img9
    global my_img6
    
    my_img9=ImageTk.PhotoImage(Image.open("C:/Users/Portu/Desktop/Spotify/cluster9.ico"))
    my_label09=Label(top7a2,image=my_img9).pack()
    boton_701a3=Button(top7a2,text="Listen a trial of the song", command= cluster9 ,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_701a3.place(x=200,y=100)
   
    my_img6=ImageTk.PhotoImage(Image.open("C:/Users/Portu/Desktop/Spotify/cluster6.ico"))
    my_label06=Label(top7a2,image=my_img6).pack()
    boton_701a36=Button(top7a2,text="Listen a trial of the song", command= cluster6 ,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_701a36.place(x=200,y=300)

    
    boton_701ea29=Button(top7a2,text="I prefer this song", command= lambda:[final70(), lista9()] ,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_701ea29.place(x=800,y=100)
    boton_7011ea26=Button(top7a2,text="I prefer this song", command=lambda:[final70(),lista6()] ,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_7011ea26.place(x=800,y=300)
    boton_salir70a2=Button(top7a2,text="Leave me go!", command= ventana.destroy,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
    boton_salir70a2.place(x=50,y=50)

Helvfont = font.Font(family="Trebuchet", size=20, weight="bold")
boton=Button(text="I want a great recommendation!",padx=10, pady=10, command=open, background="#d2af23",foreground="#002270",anchor="center",font=Helvfont)
boton.place(x=370,y=300)

#Close the main window
Helvfont12 = font.Font(family="Trebuchet", size=12, weight="bold")
boton_salir=Button(ventana,text="Leave me go!", command= ventana.destroy,background="#d2af23",foreground="#002270",anchor="center",font=Helvfont12)
boton_salir.place(x=525,y=380)
ventana.mainloop()
